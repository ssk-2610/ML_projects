# %%
import numpy as np
import h5py
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import cv2
from keras.layers import Input,Dense,Reshape,Conv2D,Dropout,multiply,Dot,Concatenate,subtract,ZeroPadding2D
from keras.layers import BatchNormalization,LeakyReLU,Flatten
from keras.layers import Conv2DTranspose as Deconv2d
from keras.models import Model
from keras.optimizers import Adam

from google.colab import files
from keras import backend as K
import smtplib

from sklearn.utils import shuffle
from google.colab import drive

# %%
def plot(A,B,C,n):

    samples = [A,B,C]
    fig = plt.figure(figsize=(3,n))
    gs = gridspec.GridSpec(3,n)
    g=0
    for i in range(3):
        for j in range(n):
            ax = plt.subplot(gs[g])
            g+=1
            plt.axis('off')
            ax.set_xticklabels([])
            ax.set_yticklabels([])
            ax.set_aspect('equal')
            if samples[i][j].shape == (32,32,1):
              plt.imshow(samples[i][j].reshape(32, 32))
            else:
              plt.imshow(samples[i][j].reshape(32,32,3))

    return fig

# %%
def ploty(A,B,n):

    samples = [A,B]
    fig = plt.figure(figsize=(3,n))
    gs = gridspec.GridSpec(3,n)
    g=0
    for i in range(2):
        for j in range(n):
            ax = plt.subplot(gs[g])
            g+=1
            plt.axis('off')
            ax.set_xticklabels([])
            ax.set_yticklabels([])
            ax.set_aspect('equal')
            if samples[i][j].shape == (32,32,1):
              plt.imshow(samples[i][j].reshape(32, 32, 1))
            else:
              plt.imshow(samples[i][j].reshape(32,32,3))

    return fig

# %%
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
from keras.datasets import cifar10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

y=x_train
x=np.sum(y, axis=3)/(3*255)
y_test=x_test
x_test=np.sum(x_test, axis=3)/(3*255)   
x_test=x_test.reshape(10000, 32, 32, 1)
y=x_train/255
y=y*2-1
x=x.reshape(50000, 32, 32, 1)
print(x.shape)
print(y.shape)
# Out:
# (50000, 32, 32, 1)
# (50000, 32, 32, 3)

# %%
  
x_shape=(32,32,1)
y_shape=(32,32,3)

# %%
def Generator():
  X = Input(shape = x_shape)  
  C1 = Conv2D(64,kernel_size = 1, strides = 1,input_shape = x_shape)(X)
  C1 = LeakyReLU(0.2)(C1)
  
  C2 = Conv2D(128,kernel_size = 2, strides = 2)(C1)  
  C2 = LeakyReLU(0.2)(C2)
  
  C3 = Conv2D(256,kernel_size = 2, strides = 2)(C2)
  C3 = LeakyReLU(0.2)(C3)
  
  C4 = Conv2D(512,kernel_size = 2, strides = 2)(C3)
  C4 = LeakyReLU(0.2)(C4)

  C5 = Conv2D(512, kernel_size = 2, strides = 2)(C4)
  C5 = LeakyReLU(0.2)(C5)
  
  
  DC0 = Deconv2d(512, kernel_size = 2, strides = 2)(C5)
  DC0 = LeakyReLU(0.2)(DC0)
  DC0 = BatchNormalization()(DC0)
  DC0 = Dropout(0.5)(DC0)
  DC0 = Concatenate(axis=3)([DC0, C4])

  
  DC1 = Deconv2d(256,kernel_size=2, strides = 2)(DC0)
  DC1 = LeakyReLU(0.2)(DC1)
  DC1 = BatchNormalization()(DC1)  
  DC1 = Dropout(0.5)(DC1)             
  DC1 = Concatenate(axis=3)([DC1,C3])

  
  DC2 = Deconv2d(128,kernel_size=2, strides = 2)(DC1)
  DC2 = LeakyReLU(0.2)(DC2)
  DC2 = BatchNormalization()(DC2)  
  DC2 = Concatenate(axis=3)([DC2,C2])
  
  DC3 = Deconv2d(64,kernel_size=2, strides = 2)(DC2)
  DC3 = LeakyReLU(0.2)(DC3)
  DC3 = BatchNormalization()(DC3)  
  DC3 = Concatenate(axis=3)([DC3,C1])
  CC4 = Conv2D(3,kernel_size=(1, 1), strides = (1, 1), activation="tanh")(DC3)
  
  m = Model(X,CC4)
  m.summary()
  return m

# %%
def Discriminator():
  X = Input(shape = x_shape)
  Y = Input(shape = y_shape)
  
  In = Concatenate(axis=3)([X,Y])
  
  C1 = Conv2D(64,kernel_size = 2, strides = 2,input_shape = x_shape)(In)
  C1 = BatchNormalization()(C1)
  C1 = LeakyReLU(0.2)(C1)
  C2 = Conv2D(128,kernel_size = 2, strides = 2)(C1)  
  C2 = BatchNormalization()(C2)
  C2 = LeakyReLU(0.2)(C2)
  
  C3 = Conv2D(256,kernel_size = 2, strides = 2)(C2)
  C3 = BatchNormalization()(C3)
  C3 = LeakyReLU(0.2)(C3)
  
  C4 = Conv2D(512,kernel_size = 1, strides = 1)(C3)
  C4 = BatchNormalization()(C4)
  C4 = LeakyReLU(0.2)(C4)
  
  D = Flatten()(C4)
  D = Dense(128)(D)
  D = Dense(1,activation='sigmoid')(D)
  
  m = Model([X,Y],D)
  m.summary()
  return m

# %%
X = Input(shape = x_shape)
Y = Input(shape = y_shape)

gen = Generator()
dis = Discriminator()

out = gen(X)
comb = dis([X,out])

out = Flatten()(out)
org = Flatten()(Y)

cos_dis = Dot(axes = 1,normalize = True)([out,org])

combined = Model([X,Y],[comb,cos_dis])
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            [(None, 32, 32, 1)]  0
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 64)   128         input_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 32, 32, 64)   0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  32896       leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 16, 16, 128)  0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 256)    131328      leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 8, 8, 256)    0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 4, 4, 512)    524800      leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 4, 4, 512)    0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 2, 2, 512)    1049088     leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 2, 2, 512)    0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 4, 4, 512)    1049088     leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 4, 4, 512)    0           conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 4, 4, 512)    2048        leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 4, 4, 512)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 4, 4, 1024)   0           dropout_2[0][0]
#                                                                  leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 8, 8, 256)    1048832     concatenate_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 8, 8, 256)    0           conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 256)    1024        leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 8, 8, 256)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 8, 8, 512)    0           dropout_3[0][0]
#                                                                  leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 16, 16, 128)  262272      concatenate_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 16, 16, 128)  0           conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 128)  512         leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 16, 16, 256)  0           batch_normalization_10[0][0]
#                                                                  leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 32, 32, 64)   65600       concatenate_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 32, 32, 64)   0           conv2d_transpose_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 64)   256         leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 32, 32, 128)  0           batch_normalization_11[0][0]
#                                                                  leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 3)    387         concatenate_8[0][0]
# ==================================================================================================
# Total params: 4,168,259
# Trainable params: 4,166,339
# Non-trainable params: 1,920
# __________________________________________________________________________________________________
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            [(None, 32, 32, 1)]  0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 32, 32, 4)    0           input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 64)   1088        concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 64)   256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 16, 16, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 128)    32896       leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 128)    512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 8, 8, 128)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 4, 4, 256)    131328      leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 4, 4, 256)    1024        conv2d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 4, 4, 256)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 4, 4, 512)    131584      leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 4, 4, 512)    2048        conv2d_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 4, 4, 512)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 8192)         0           leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          1048704     flatten_3[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            129         dense_2[0][0]
# ==================================================================================================
# Total params: 1,349,569
# Trainable params: 1,347,649
# Non-trainable params: 1,920
# __________________________________________________________________________________________________

# %%
genLoss=[]
disLoss=[]

# %%
epochs = 100
batch_size = 64
n_example = 50000
batches = int(n_example/batch_size)
dis_updates = 2
gen_updates = 1
zero=np.zeros((batch_size,1))
one=np.ones((batch_size,1))*0.9
d_loss_factor = batches*2*dis_updates
g_loss_factor = batches*gen_updates
reuse = False
adams = Adam(lr = 0.001)

# %%
if(reuse == True):
  gen.load_weights("gdrive/My Drive/newGAN/Generator.h5")
  dis.load_weights("gdrive/My Drive/newGAN/Discriminator.h5")

# %%
for epoch in range(epochs):
  print("--------------")
  print("For Epoch:"+str(epoch))
  
  g_loss = 0
  d_loss = 0
  
  print("Training Discriminator")
  
  i = shuffle(range(n_example))
  
  dis.trainable = True
  dis.compile(loss = "binary_crossentropy",optimizer = adams)
  
  for j in range(dis_updates):
      
    for b in range(batches):
        
      x_batch = x[i[b*batch_size:(b+1)*batch_size]]
      y_batch = y[i[b*batch_size:(b+1)*batch_size]]
      
      pre_batch = gen.predict(x_batch)
      
      d_loss += dis.train_on_batch([x_batch,y_batch],one)
      d_loss += dis.train_on_batch([x_batch,pre_batch],zero)
      
  print("Training Generator")
  
  dis.trainable = False
  combined.compile(loss  = "binary_crossentropy", optimizer = adams)  
  dis.compile(loss = "binary_crossentropy",optimizer = adams)
        
  for  j in range(gen_updates):
    
    for b in range(batches):
      
      x_batch = x[i[b*batch_size:(b+1)*batch_size]]
      y_batch = y[i[b*batch_size:(b+1)*batch_size]]
      gl,_,_ = combined.train_on_batch([x_batch,y_batch],[one,one])
      g_loss += gl
      
  g_loss /= g_loss_factor
  d_loss /= d_loss_factor
      
  print("Discriminator Loss:"+str(d_loss))
  print("Generator loss:"+str(g_loss))
  
  genLoss.append(g_loss)
  disLoss.append(d_loss)
  
  gen.save_weights("gdrive/MyDrive/Colab Notebooks/Generator.h5")
  dis.save_weights("gdrive/MyDrive/Colab Notebooks/Discriminator.h5")
  


  plt_indices = np.random.randint(50000,size=3)
  plt_a = x[plt_indices]
  plt_b = gen.predict(plt_a)
  plt_b = (plt_b+1)/2
  plt_c = (y[plt_indices]+1)/2
  fig = plot(plt_a,plt_b,plt_c,3)
  plt.show()
  plt.close(fig)
plt.plot(genLoss, c='r', label="Generator Loss")
plt.plot(disLoss, c='b', label="Discriminator Loss")
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# --------------
# For Epoch:0
# Training Discriminator
# Training Generator
# Discriminator Loss:0.16480449313406442
# Generator loss:0.6678725761884916
# --------------
# For Epoch:1
# Training Discriminator
# Training Generator
# Discriminator Loss:0.1668403046798826
# Generator loss:0.6686881885180552
# --------------
# For Epoch:2
# Training Discriminator
# Training Generator
# Discriminator Loss:0.1668930461025543
# Generator loss:0.669407531103923
# --------------
# For Epoch:3
# Training Discriminator
# Training Generator
# Discriminator Loss:0.1653436698456465
# Generator loss:0.6699758600181257
# --------------
# For Epoch:4
# Training Discriminator
# Training Generator
# Discriminator Loss:0.16670358619615627
# Generator loss:0.6667446753584927
# --------------
# For Epoch:5
# Training Discriminator
# Training Generator
# Discriminator Loss:0.16553988171770276
# Generator loss:0.6685400426616742
# --------------
# For Epoch:6
# Training Discriminator
